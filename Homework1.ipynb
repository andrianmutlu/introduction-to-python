# %% [markdown]
# <a href="https://colab.research.google.com/github/andrianmutlu/introduction-to-python/blob/master/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Introduction to Pyhton Homework1 by Mutlu Senturk

#list of odd numbers between 1 and 20 
list1=list(range(1,20,2))
#list of even numbers between 1 and 20
list2=list(range(2,21,2))
#merge list
list3=list1+list2
#multiply by 2
list4=[num*2 for num in list3] 

#print the data type
for num in list4:
    print(type(num))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
